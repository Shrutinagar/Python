# %% [markdown]
# # Hotel Recommendation System

# %%
recommender("FR", "Leisure")
# Out:
#                                  Hotel_Name  Average_Score  \
# 0                                Ritz Paris            9.8
# 1       H tel de La Tamise Esprit de France            9.6
# 2                     Le Narcisse Blanc Spa            9.5
# 3                 Hotel The Peninsula Paris            9.5
# 4                               Hotel Monge            9.4
# 5                            Nolinski Paris            9.4
# 6                      La Chambre du Marais            9.4
# 7                       Hotel Eiffel Blomet            9.4
# 8  Goralska R sidences H tel Paris Bastille            9.4
# 9                          H tel D Aubusson            9.4
#
#                                        Hotel_Address
# 0            15 Place Vend me 1st arr 75001 Paris FR
# 1               4 rue d Alger 1st arr 75001 Paris FR
# 2  19 Boulevard De La Tour Maubourg 7th arr 75007...
# 3           19 avenue Kleber 16th arr 75116 Paris FR
# ...

# %%
recommender("ES", "Solo Traveler")
# Out:
#                  Hotel_Name  Average_Score  \
# 0         Hotel Casa Camper            9.6
# 1          Hotel The Serras            9.6
# 2     H10 Casa Mimosa 4 Sup            9.6
# 3    Mercer Hotel Barcelona            9.5
# 4    Catalonia Square 4 Sup            9.4
# 5      The One Barcelona GL            9.4
# 6           Hotel Palace GL            9.4
# 7  The Wittmore Adults Only            9.4
# 8        Hotel Margot House            9.4
# 9      Catalonia Magdalenes            9.4
#
#                                        Hotel_Address
# 0       Elisabets 11 Ciutat Vella 08001 Barcelona ES
# 1  Passeig de Colom 9 Ciutat Vella 08002 Barcelon...
# 2         Pau Claris 179 Eixample 08037 Barcelona ES
# 3       Dels Lledo 7 Ciutat Vella 08003 Barcelona ES
# 4      Ronda Sant Pere 9 Eixample 08010 Barcelona ES
# 5  277 Carrer de Proven a Eixample 08037 Barcelon...
# 6  Gran Via de les Corts Catalanes 668 Eixample 0...
# 7       Riudarenes 7 Ciutat Vella 08002 Barcelona ES
# ...

# %% [markdown]
# # Python Code

# %% [markdown]
# Importing libraries

# %%
# !pip install pandas --upgrade --quiet

# %%
import pandas as pd
import numpy as np

# %%
# !pip install nltk
import nltk
# downloading ntlk modules
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
nltk.download('omw-1.4')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem.wordnet import WordNetLemmatizer
from ast import literal_eval
# Out:
# ...
# [nltk_data] Downloading package punkt to /home/jovyan/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/jovyan/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/jovyan/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
# !pip install opendatasets

# %%
import opendatasets as od

data = od.download("https://www.kaggle.com/datasets/jiashenliu/515k-hotel-reviews-data-in-europe")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: shrutinagar00
# Your Kaggle Key: ········
# ...
# 100%|██████████| 45.1M/45.1M [00:04<00:00, 10.4MB/s]

# %%
# reading the CSV file
# location of file in directory after uploading using opendatasets
data = pd.read_csv('515k-hotel-reviews-data-in-europe/Hotel_Reviews.csv')

# %%
# uploading data set
# data = pd.read_csv('Hotel_Reviews.csv')

# %%
data
# Out:
#                                             Hotel_Address  \
# 0        s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 1        s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 2        s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 3        s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 4        s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# ...                                                   ...
# 515733  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515734  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515735  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515736  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515737  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
#
#         Additional_Number_of_Scoring Review_Date  Average_Score  \
# 0                                194    8/3/2017            7.7
# 1                                194    8/3/2017            7.7
# 2                                194   7/31/2017            7.7
# ...

# %%
data.head()
# Out:
#                                        Hotel_Address  \
# 0   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 1   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 2   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 3   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 4   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
#
#    Additional_Number_of_Scoring Review_Date  Average_Score   Hotel_Name  \
# 0                           194    8/3/2017            7.7  Hotel Arena
# 1                           194    8/3/2017            7.7  Hotel Arena
# 2                           194   7/31/2017            7.7  Hotel Arena
# 3                           194   7/31/2017            7.7  Hotel Arena
# 4                           194   7/24/2017            7.7  Hotel Arena
#
#   Reviewer_Nationality                                    Negative_Review  \
# 0              Russia    I am so angry that i made this post available...
# ...

# %%
data.tail()
# Out:
#                                             Hotel_Address  \
# 515733  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515734  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515735  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515736  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515737  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
#
#         Additional_Number_of_Scoring Review_Date  Average_Score  \
# 515733                           168   8/30/2015            8.1
# 515734                           168   8/22/2015            8.1
# 515735                           168   8/19/2015            8.1
# 515736                           168   8/17/2015            8.1
# 515737                           168    8/9/2015            8.1
#
#                    Hotel_Name Reviewer_Nationality  \
# 515733  Atlantis Hotel Vienna              Kuwait
# 515734  Atlantis Hotel Vienna             Estonia
# 515735  Atlantis Hotel Vienna               Egypt
# ...

# %%
data.shape
# Out:
# (515738, 17)

# %%
data.size
# Out:
# 8767546

# %%
data.info
# Out:
# <bound method DataFrame.info of                                             Hotel_Address  \
# 0        s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 1        s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 2        s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 3        s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 4        s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# ...                                                   ...
# 515733  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515734  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515735  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515736  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515737  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
#
#         Additional_Number_of_Scoring Review_Date  Average_Score  \
# 0                                194    8/3/2017            7.7
# 1                                194    8/3/2017            7.7
# ...

# %%
print(data.Hotel_Address)
print(data.Hotel_Address.head())
# Out:
# 0          s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 1          s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 2          s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 3          s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 4          s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
#                                 ...
# 515733    Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515734    Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515735    Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515736    Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515737    Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# Name: Hotel_Address, Length: 515738, dtype: object
# 0     s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 1     s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 2     s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 3     s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# 4     s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
# ...

# %% [markdown]
# For simplicity, change countries names to countries Alpha-2 codes
#
# ** Alpha Codes are Country codes **
#
# 1. Netherlands NL
# 2. United Kingdom UK
# 3. France FR
# 4. Spain ES
# 5. Italy IT
# 6. Austria AT

# %%
data.Hotel_Address = data.Hotel_Address.str.replace("Netherlands", "NL")
data.Hotel_Address = data.Hotel_Address.str.replace("United Kingdom", "UK")
data.Hotel_Address = data.Hotel_Address.str.replace("France", "FR")
data.Hotel_Address = data.Hotel_Address.str.replace("Spain", "ES")
data.Hotel_Address = data.Hotel_Address.str.replace("Italy", "IT")
data.Hotel_Address = data.Hotel_Address.str.replace("Austria", "AT")

# %%
data.Hotel_Address
# Out:
# 0           s Gravesandestraat 55 Oost 1092 AA Amsterdam NL
# 1           s Gravesandestraat 55 Oost 1092 AA Amsterdam NL
# 2           s Gravesandestraat 55 Oost 1092 AA Amsterdam NL
# 3           s Gravesandestraat 55 Oost 1092 AA Amsterdam NL
# 4           s Gravesandestraat 55 Oost 1092 AA Amsterdam NL
#                                 ...
# 515733    Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515734    Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515735    Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515736    Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515737    Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# Name: Hotel_Address, Length: 515738, dtype: object

# %% [markdown]
# Splitting Hotel Address and picking out the last string which would be country (eg NL, ES)
# - store them in new column by the name "countries"

# %%
data["countries"] = data.Hotel_Address.apply(lambda x: x.split(' ')[-1])

# %%
data.countries
# Out:
# 0         NL
# 1         NL
# 2         NL
# 3         NL
# 4         NL
#           ..
# 515733    AT
# 515734    AT
# 515735    AT
# 515736    AT
# 515737    AT
# Name: countries, Length: 515738, dtype: object

# %%
print(data.countries.unique())
# Out:
# ['NL' 'UK' 'FR' 'ES' 'IT' 'AT']

# %%
data
# Out:
#                                             Hotel_Address  \
# 0         s Gravesandestraat 55 Oost 1092 AA Amsterdam NL
# 1         s Gravesandestraat 55 Oost 1092 AA Amsterdam NL
# 2         s Gravesandestraat 55 Oost 1092 AA Amsterdam NL
# 3         s Gravesandestraat 55 Oost 1092 AA Amsterdam NL
# 4         s Gravesandestraat 55 Oost 1092 AA Amsterdam NL
# ...                                                   ...
# 515733  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515734  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515735  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515736  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515737  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
#
#         Additional_Number_of_Scoring Review_Date  Average_Score  \
# 0                                194    8/3/2017            7.7
# 1                                194    8/3/2017            7.7
# 2                                194   7/31/2017            7.7
# ...

# %%
data.columns
# Out:
# Index(['Hotel_Address', 'Additional_Number_of_Scoring', 'Review_Date',
#        'Average_Score', 'Hotel_Name', 'Reviewer_Nationality',
#        'Negative_Review', 'Review_Total_Negative_Word_Counts',
#        'Total_Number_of_Reviews', 'Positive_Review',
#        'Review_Total_Positive_Word_Counts',
#        'Total_Number_of_Reviews_Reviewer_Has_Given', 'Reviewer_Score', 'Tags',
#        'days_since_review', 'lat', 'lng', 'countries'],
#       dtype='object')

# %% [markdown]
# Columns required for recommender are:
# 1. Hotel_Address
# 2. Average_Score
# 3. Hotel_Name
# 4. Tags
# 5. countries

# %%
data
# Out:
#                                             Hotel_Address  \
# 0         s Gravesandestraat 55 Oost 1092 AA Amsterdam NL
# 1         s Gravesandestraat 55 Oost 1092 AA Amsterdam NL
# 2         s Gravesandestraat 55 Oost 1092 AA Amsterdam NL
# 3         s Gravesandestraat 55 Oost 1092 AA Amsterdam NL
# 4         s Gravesandestraat 55 Oost 1092 AA Amsterdam NL
# ...                                                   ...
# 515733  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515734  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515735  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515736  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
# 515737  Wurzbachgasse 21 15 Rudolfsheim F nfhaus 1150 ...
#
#         Additional_Number_of_Scoring Review_Date  Average_Score  \
# 0                                194    8/3/2017            7.7
# 1                                194    8/3/2017            7.7
# 2                                194   7/31/2017            7.7
# ...

# %% [markdown]
# Dropping unnecessary columns
#
# - axis = 1 (represents columns)
# - axis = 0 (represents rows)

# %%
data.drop(['Additional_Number_of_Scoring',
           'Review_Date', 'Reviewer_Nationality',
           'Negative_Review', 'Review_Total_Negative_Word_Counts',
           'Total_Number_of_Reviews', 'Positive_Review',
           'Review_Total_Positive_Word_Counts',
           'Total_Number_of_Reviews_Reviewer_Has_Given', 'Reviewer_Score',
           'days_since_review', 'lat', 'lng'],axis = 1,inplace=True)

# %%
data.columns
# Out:
# Index(['Hotel_Address', 'Average_Score', 'Hotel_Name', 'Tags', 'countries'], dtype='object')

# %% [markdown]
# Create a function to convert the strings of list into a normal list
# - Getting rid of the punctuation

# %%
def impute(column):
    column = column[0]
    if (type(column) != list):
        return "".join(literal_eval(column))
        # literal_eval to get rid of the punctuation
    else:
        return column

# %%
data.dtypes
# Out:
# Hotel_Address     object
# Average_Score    float64
# Hotel_Name        object
# Tags              object
# countries         object
# dtype: object

# %%
data.columns[0]
#in above function we start from very first column ie on 0th index
    # also tags column is in form of list so the func will not act on Tags
    # In tags '' and , are required
# Out:
# 'Hotel_Address'

# %%
data.head()
# Out:
#                                       Hotel_Address  Average_Score  \
# 0   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
# 1   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
# 2   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
# 3   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
# 4   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
#
#     Hotel_Name                                               Tags countries
# 0  Hotel Arena  [' Leisure trip ', ' Couple ', ' Duplex Double...        NL
# 1  Hotel Arena  [' Leisure trip ', ' Couple ', ' Duplex Double...        NL
# 2  Hotel Arena  [' Leisure trip ', ' Family with young childre...        NL
# 3  Hotel Arena  [' Leisure trip ', ' Solo traveler ', ' Duplex...        NL
# 4  Hotel Arena  [' Leisure trip ', ' Couple ', ' Suite ', ' St...        NL

# %%
# apply impute function on dataset
data["Tags"] = data[["Tags"]].apply(impute, axis=1)
data.head()
# Out:
#                                       Hotel_Address  Average_Score  \
# 0   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
# 1   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
# 2   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
# 3   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
# 4   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
#
#     Hotel_Name                                               Tags countries
# 0  Hotel Arena   Leisure trip  Couple  Duplex Double Room  Sta...        NL
# 1  Hotel Arena   Leisure trip  Couple  Duplex Double Room  Sta...        NL
# 2  Hotel Arena   Leisure trip  Family with young children  Dup...        NL
# 3  Hotel Arena   Leisure trip  Solo traveler  Duplex Double Ro...        NL
# 4  Hotel Arena   Leisure trip  Couple  Suite  Stayed 2 nights ...        NL

# %% [markdown]
# Converting tags and countries data to lowercase

# %%
data["Tags"] = data["Tags"].str.lower()
data["countries"] = data["countries"].str.lower()

# %%
data.head()
# Out:
#                                       Hotel_Address  Average_Score  \
# 0   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
# 1   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
# 2   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
# 3   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
# 4   s Gravesandestraat 55 Oost 1092 AA Amsterdam NL            7.7
#
#     Hotel_Name                                               Tags countries
# 0  Hotel Arena   leisure trip  couple  duplex double room  sta...        nl
# 1  Hotel Arena   leisure trip  couple  duplex double room  sta...        nl
# 2  Hotel Arena   leisure trip  family with young children  dup...        nl
# 3  Hotel Arena   leisure trip  solo traveler  duplex double ro...        nl
# 4  Hotel Arena   leisure trip  couple  suite  stayed 2 nights ...        nl

# %% [markdown]
# ## Defining Recommender Function

# %%
def recommender(location, description):
    # dividing the texts into small words/tokens
    description = description.lower()
    word_tokenize(description)
    
    #applying stopwords - eg, in, or, and etc.
    stop_words = stopwords.words('english')
    
    #applying lemmatization (base words, cats -- cat, sleeping -- sleep)
    lemm = WordNetLemmatizer()
    
    #connecting packages and filtering
    filtered = {word for word in description if not word in stop_words}
    filtered_set = set()
    for fs in filtered:
        filtered_set.add(lemm.lemmatize(fs))
        
    # creating variable that takes in the location
    # and retuns the following features:
    country = data[data['countries'] == location.lower()]
    country = country.set_index(np.arange(country.shape[0]))
    list1 = []; list2 = []; cos = [];
    
    for i in range(country.shape[0]):
        temp_token = word_tokenize(country["Tags"][i])
        temp_set = [word for word in temp_token if not word in stop_words]
        temp2_set = set()
        for s in temp_set:
            temp2_set.add(lemm.lemmatize(s))
        vector = temp2_set.intersection(filtered_set)
        cos.append(len(vector))
            
    # applying cosine similarity - to what degree 
    # search keywords match the data available
    country['similarity'] = cos
    country = country.sort_values(by = 'similarity', ascending = False)
    country.drop_duplicates(subset="Hotel_Name", keep = 'first', inplace = True)
    country.sort_values("Average_Score", ascending = False, inplace = True)
    country.reset_index(inplace = True)
    return country[["Hotel_Name", "Average_Score", "Hotel_Address"]].head(10)

# %%
# enter input
recommender("FR", "Business Trip")
# Out:
#                                  Hotel_Name  Average_Score  \
# 0                                Ritz Paris            9.8
# 1       H tel de La Tamise Esprit de France            9.6
# 2                     Le Narcisse Blanc Spa            9.5
# 3                 Hotel The Peninsula Paris            9.5
# 4                      La Chambre du Marais            9.4
# 5  Goralska R sidences H tel Paris Bastille            9.4
# 6                            Nolinski Paris            9.4
# 7                     Splendide Royal Paris            9.4
# 8                               Hotel Monge            9.4
# 9                       Hotel Eiffel Blomet            9.4
#
#                                        Hotel_Address
# 0            15 Place Vend me 1st arr 75001 Paris FR
# 1               4 rue d Alger 1st arr 75001 Paris FR
# 2  19 Boulevard De La Tour Maubourg 7th arr 75007...
# 3           19 avenue Kleber 16th arr 75116 Paris FR
# ...

# %% [markdown]
# ### Data Set
# https://www.kaggle.com/datasets/jiashenliu/515k-hotel-reviews-data-in-europe
#
# ##### 515K Hotels Reviews Data in EUROPE
